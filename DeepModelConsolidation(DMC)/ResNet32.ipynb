# %%
import torch.optim as optim
from torch import nn
import torch
import torchvision
import torchvision.transforms as transforms
import math
from PIL import Image
from torchvision.datasets import CIFAR100
import matplotlib.pyplot as plt
import os
import numpy as np
import pickle
from torchsummary import summary

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#All the parameters
epoch = 100
lr = 0.1
weight_decay = 0.0001
momentum = 0.9
gamma = 0.95
resnet_type = 5

# %%
class ResidualBlock(nn.Module):
  def __init__(self, channel_num, stride, downsample_layer = None):
    super(ResidualBlock, self).__init__()

    self.downsample = downsample_layer
    
    self.conv1 = nn.Sequential(
        nn.Conv2d(int(channel_num/stride), channel_num, 3, stride, padding=1),
        nn.BatchNorm2d(channel_num),
        nn.ReLU(),
    )
    self.conv2 = nn.Sequential(
        nn.Conv2d(channel_num, channel_num, 3, int(stride/stride), padding=1),
        nn.BatchNorm2d(channel_num),
    )
    self.relu = nn.ReLU() #Definiramo izvan bloka zbog skip connectiona

  def forward(self, x):
    skip_connection = x
    x = self.conv1(x)
    x = self.conv2(x)
    if(skip_connection.shape != x.shape):
      skip_connection = self.downsample(skip_connection)
    x = skip_connection + x
    x = self.relu(x)
    return x

# %%
class ResidualNetwork(nn.Module):
  def __init__(self, channel_num=16):
    super(ResidualNetwork, self).__init__()

    self.conv1 = nn.Sequential(
      nn.Conv2d(3, channel_num, 3, padding=1),
      nn.BatchNorm2d(channel_num),
      nn.ReLU(),
    )

    res_blocks = []

    for i in range(3 * resnet_type):
      if(i != 0 and i % resnet_type == 0):
        channel_num = channel_num*2
        res_blocks.append(ResidualBlock(channel_num, 2, nn.Sequential(
            nn.Conv2d(int(channel_num/2), channel_num, 1, 2),
            nn.BatchNorm2d(channel_num),
        )))
      else:
        res_blocks.append(ResidualBlock(channel_num, 1))

    self.residualblocks = nn.Sequential(*res_blocks)

    self.pool = nn.AdaptiveAvgPool2d((1, 1))
    self.fc = nn.Linear(64, 100, bias=True)

  def forward(self, x):
    x = self.conv1(x)
    x = self.residualblocks(x)
    x = self.pool(x)
    x = x.reshape(x.shape[0], -1)
    out = self.fc(x)

    return out

# %%
trainTransform = transforms.Compose([
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616))])

testTransform = transforms.Compose([    
    transforms.ToTensor(),
    transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616))])


trainSet = torchvision.datasets.CIFAR100(root='./drive/MyDrive/Zavrsni/data', train=True,
                    download=False, transform=trainTransform)
testSet = torchvision.datasets.CIFAR100(root='./drive/MyDrive/Zavrsni/data', train=False,
                    download=False, transform=testTransform)

trainLoader = torch.utils.data.DataLoader(trainSet, batch_size=128,
                                          shuffle=True, num_workers=0)

testLoader = torch.utils.data.DataLoader(testSet, batch_size=128,
                                         shuffle=True, num_workers=0)

classes=pickle.load(open('./drive/MyDrive/Zavrsni/data/cifar-100-python/meta', 'rb'))
classes=classes['fine_label_names']

# %%
def evaluate(net, type, save_path):
    """
    Performs the evaluation of the current performance of a
    given convolutional network. It can perform the evaluation on 
    both training and testing sets. Standard evaluation metrics are
    calcualted such as, accuracy and confusion matrix.
    Parameters
    ----------
    net: ConvolutionalModel
        ConvNet whose performance needs to be evaluated.
    type: bool
        True if eval is made on testing set, false otherwise
    Return
    ------
    loss
        Current loss on the chosen set
    accuracy
        Current acc on the chosen set
    """
    device = torch.device('cuda')
    f = open(save_path, "a+")
    net.eval()
    total = 0
    correct = 0
    confMatrix = np.zeros((100, 100), int)
    lossFunc = nn.CrossEntropyLoss()
    accLoss = 0
    if type:
        with torch.no_grad():
            for data in testLoader:
                images, labels = data
                images = images.to(device=device)
                labels = labels.to(device=device)

                output = net.forward(images)
                loss = lossFunc(output, labels)
                _, predictions = torch.max(output.data, 1)
                total += labels.size(0)
                accLoss += loss.item()
                correct += (predictions == labels).sum().item()
                for j in range(labels.size(0)):
                    confMatrix[predictions[j], labels[j]] += 1
    else:
        with torch.no_grad():
            for data in trainLoader:
                images, labels = data
                images = images.to(device=device)
                labels = labels.to(device=device)

                output = net.forward(images)
                loss = lossFunc(output, labels)
                _, predictions = torch.max(output.data, 1)
                total += labels.size(0)
                accLoss += loss.item()
                correct += (predictions == labels).sum().item()
                for j in range(labels.size(0)):
                    confMatrix[predictions[j], labels[j]] += 1

    print("Accuracy of the neural network on CIFAR_100 is: %.2f %%" %((correct/total)*100))
    f.write("Accuracy: " + str(((correct/total)*100)) + '\n')
    f.write(str(classes) + '\n')
    f.write(str(confMatrix) + '\n')
    prec, recall = specificMetrics(confMatrix)
    f.write(str(prec) + '\n')
    f.write(str(recall) + '\n')
    f.close()
    return (accLoss/(total/trainLoader.batch_size)), (correct/total)

def specificMetrics(confMatrix):
    """
    Calculates precision and recall from a given confusion
    matrix and returns calculated metrics.
    Parameters
    ----------
    confMatrix: n x n numpy array
        Made from the predictions and true labels of a
        given set of data
    Return
    ------
    precc
        Precision on all classes
    recal 
        Recall on all classes
    """
    precc = np.zeros(np.size(confMatrix, 0))
    recal = np.zeros(np.size(confMatrix, 0))
    for i in range(np.size(confMatrix, 0)):
        tp = 0
        fp = 0
        fn = 0
        for j in range(np.size(confMatrix, 0)):
            if i == j:
                tp += confMatrix[i, j]
            else:
                fn += confMatrix[j, i]
                fp += confMatrix[i, j]
            
        precc[i] += tp/(tp + fp)
        recal[i] += tp/(tp + fn)

    return precc, recal

# %%
def plot_training_progress(save_dir, data):
  fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

  linewidth = 2
  legend_size = 10
  train_color = 'm'
  val_color = 'c'

  num_points = len(data['train_loss'])
  x_data = np.linspace(1, num_points, num_points)
  ax1.set_title('Cross-entropy loss')
  ax1.plot(x_data, data['train_loss'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax1.plot(x_data, data['valid_loss'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax1.legend(loc='upper right', fontsize=legend_size)
  ax2.set_title('Average class accuracy')
  ax2.plot(x_data, data['train_acc'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax2.plot(x_data, data['valid_acc'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax2.legend(loc='upper left', fontsize=legend_size)
  ax3.set_title('Learning rate')
  ax3.plot(x_data, data['lr'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='learning_rate')
  ax3.legend(loc='upper left', fontsize=legend_size)

  save_path = os.path.join(save_dir, 'plots/training_plot7.png')
  print('Plotting in: ', save_path)
  plt.savefig(save_path)

# %%
def trainNetwork():
    """Performs a standard procedure for training a neural network.
    Training progress after each learning epoch is evaluated in order to
    gain insigth into ConvNets continuous performance.
    Important notes
    ---------------
    Loss function: Cross entropy loss

    Optimizer: SGD
    
    Scheduler: MultiStepLR
    """
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []
    SAVE_DIR = '/content/drive/MyDrive/Zavrsni'
    device = torch.device('cuda')

    net = ResidualNetwork().to(device=device)
    summary(net, (3, 32, 32))

    lossFunc = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50,75], gamma=gamma)
    schedulerExp = optim.lr_scheduler.ExponentialLR(optimizer, gamma=gamma)
    
    for e in range(epoch):
    
        accLoss = 0.0

        for i, data in enumerate(trainLoader, 0):
            inputs, labels = data
            inputs = inputs.to(device=device)
            labels = labels.to(device=device)

            optimizer.zero_grad()

            outputs = net.forward(inputs)
            loss = lossFunc(outputs, labels)
            loss.backward()
            optimizer.step()

            accLoss += loss.item()

            if i % 100 == 0:
                print("Epoch: %d, Iteration: %5d, Loss: %.3f" % ((e + 1), (i), (accLoss / (i + 1))))
                
        train_loss, train_acc = evaluate(net, False, os.path.join(SAVE_DIR, "eval/train_eval7"))
        val_loss, val_acc = evaluate(net, True, os.path.join(SAVE_DIR, "eval/test_eval7"))

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [val_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [val_acc]
        plot_data['lr'] += [schedulerExp.get_last_lr()]

        schedulerExp.step()
    
    val_loss, val_acc = evaluate(net, True, os.path.join(SAVE_DIR, "eval/final_eval7"))
    plot_training_progress(SAVE_DIR, plot_data)
    PATH = os.path.join(SAVE_DIR, "CIFAR_100/cifar_net7.pth")
    torch.save(net.state_dict(), PATH)

trainNetwork()
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 16, 32, 32]           2,320
#        BatchNorm2d-5           [-1, 16, 32, 32]              32
#               ReLU-6           [-1, 16, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]           2,320
#        BatchNorm2d-8           [-1, 16, 32, 32]              32
#               ReLU-9           [-1, 16, 32, 32]               0
#     ResidualBlock-10           [-1, 16, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-12           [-1, 16, 32, 32]              32
#              ReLU-13           [-1, 16, 32, 32]               0
#            Conv2d-14           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-15           [-1, 16, 32, 32]              32
#              ReLU-16           [-1, 16, 32, 32]               0
#     ResidualBlock-17           [-1, 16, 32, 32]               0
#            Conv2d-18           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-19           [-1, 16, 32, 32]              32
#              ReLU-20           [-1, 16, 32, 32]               0
#            Conv2d-21           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-22           [-1, 16, 32, 32]              32
#              ReLU-23           [-1, 16, 32, 32]               0
#     ResidualBlock-24           [-1, 16, 32, 32]               0
#            Conv2d-25           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-26           [-1, 16, 32, 32]              32
#              ReLU-27           [-1, 16, 32, 32]               0
#            Conv2d-28           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-29           [-1, 16, 32, 32]              32
#              ReLU-30           [-1, 16, 32, 32]               0
#     ResidualBlock-31           [-1, 16, 32, 32]               0
#            Conv2d-32           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-33           [-1, 16, 32, 32]              32
#              ReLU-34           [-1, 16, 32, 32]               0
#            Conv2d-35           [-1, 16, 32, 32]           2,320
#       BatchNorm2d-36           [-1, 16, 32, 32]              32
#              ReLU-37           [-1, 16, 32, 32]               0
#     ResidualBlock-38           [-1, 16, 32, 32]               0
#            Conv2d-39           [-1, 32, 16, 16]           4,640
#       BatchNorm2d-40           [-1, 32, 16, 16]              64
#              ReLU-41           [-1, 32, 16, 16]               0
#            Conv2d-42           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-43           [-1, 32, 16, 16]              64
#            Conv2d-44           [-1, 32, 16, 16]             544
#       BatchNorm2d-45           [-1, 32, 16, 16]              64
#              ReLU-46           [-1, 32, 16, 16]               0
#     ResidualBlock-47           [-1, 32, 16, 16]               0
#            Conv2d-48           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-49           [-1, 32, 16, 16]              64
#              ReLU-50           [-1, 32, 16, 16]               0
#            Conv2d-51           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-52           [-1, 32, 16, 16]              64
#              ReLU-53           [-1, 32, 16, 16]               0
#     ResidualBlock-54           [-1, 32, 16, 16]               0
#            Conv2d-55           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-56           [-1, 32, 16, 16]              64
#              ReLU-57           [-1, 32, 16, 16]               0
#            Conv2d-58           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-59           [-1, 32, 16, 16]              64
#              ReLU-60           [-1, 32, 16, 16]               0
#     ResidualBlock-61           [-1, 32, 16, 16]               0
#            Conv2d-62           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-63           [-1, 32, 16, 16]              64
#              ReLU-64           [-1, 32, 16, 16]               0
#            Conv2d-65           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-66           [-1, 32, 16, 16]              64
#              ReLU-67           [-1, 32, 16, 16]               0
#     ResidualBlock-68           [-1, 32, 16, 16]               0
#            Conv2d-69           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-70           [-1, 32, 16, 16]              64
#              ReLU-71           [-1, 32, 16, 16]               0
#            Conv2d-72           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-73           [-1, 32, 16, 16]              64
#              ReLU-74           [-1, 32, 16, 16]               0
#     ResidualBlock-75           [-1, 32, 16, 16]               0
#            Conv2d-76             [-1, 64, 8, 8]          18,496
#       BatchNorm2d-77             [-1, 64, 8, 8]             128
#              ReLU-78             [-1, 64, 8, 8]               0
#            Conv2d-79             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-80             [-1, 64, 8, 8]             128
#            Conv2d-81             [-1, 64, 8, 8]           2,112
#       BatchNorm2d-82             [-1, 64, 8, 8]             128
#              ReLU-83             [-1, 64, 8, 8]               0
#     ResidualBlock-84             [-1, 64, 8, 8]               0
#            Conv2d-85             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-86             [-1, 64, 8, 8]             128
#              ReLU-87             [-1, 64, 8, 8]               0
#            Conv2d-88             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-89             [-1, 64, 8, 8]             128
#              ReLU-90             [-1, 64, 8, 8]               0
#     ResidualBlock-91             [-1, 64, 8, 8]               0
#            Conv2d-92             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-93             [-1, 64, 8, 8]             128
#              ReLU-94             [-1, 64, 8, 8]               0
#            Conv2d-95             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-96             [-1, 64, 8, 8]             128
#              ReLU-97             [-1, 64, 8, 8]               0
#     ResidualBlock-98             [-1, 64, 8, 8]               0
#            Conv2d-99             [-1, 64, 8, 8]          36,928
#      BatchNorm2d-100             [-1, 64, 8, 8]             128
#             ReLU-101             [-1, 64, 8, 8]               0
#           Conv2d-102             [-1, 64, 8, 8]          36,928
#      BatchNorm2d-103             [-1, 64, 8, 8]             128
#             ReLU-104             [-1, 64, 8, 8]               0
#    ResidualBlock-105             [-1, 64, 8, 8]               0
#           Conv2d-106             [-1, 64, 8, 8]          36,928
#      BatchNorm2d-107             [-1, 64, 8, 8]             128
#             ReLU-108             [-1, 64, 8, 8]               0
#           Conv2d-109             [-1, 64, 8, 8]          36,928
#      BatchNorm2d-110             [-1, 64, 8, 8]             128
#             ReLU-111             [-1, 64, 8, 8]               0
#    ResidualBlock-112             [-1, 64, 8, 8]               0
# AdaptiveAvgPool2d-113             [-1, 64, 1, 1]               0
#           Linear-114                  [-1, 100]           6,500
# ================================================================
# Total params: 473,988
# Trainable params: 473,988
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 8.22
# Params size (MB): 1.81
# Estimated Total Size (MB): 10.04
# ----------------------------------------------------------------
# Epoch: 1, Iteration:     0, Loss: 5.044
# Epoch: 1, Iteration:   100, Loss: 4.550
# Epoch: 1, Iteration:   200, Loss: 4.425
# Epoch: 1, Iteration:   300, Loss: 4.343
# Accuracy of the neural network on CIFAR_100 is: 6.44 %
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:98: RuntimeWarning: invalid value encountered in long_scalars
# Accuracy of the neural network on CIFAR_100 is: 7.56 %
# Epoch: 2, Iteration:     0, Loss: 4.084
# Epoch: 2, Iteration:   100, Loss: 4.155
# Epoch: 2, Iteration:   200, Loss: 4.098
# Epoch: 2, Iteration:   300, Loss: 4.050
# Accuracy of the neural network on CIFAR_100 is: 10.26 %
# Accuracy of the neural network on CIFAR_100 is: 12.02 %
# Epoch: 3, Iteration:     0, Loss: 3.831
# Epoch: 3, Iteration:   100, Loss: 3.831
# Epoch: 3, Iteration:   200, Loss: 3.797
# Epoch: 3, Iteration:   300, Loss: 3.772
# Accuracy of the neural network on CIFAR_100 is: 13.91 %
# Accuracy of the neural network on CIFAR_100 is: 15.16 %
# Epoch: 4, Iteration:     0, Loss: 3.698
# Epoch: 4, Iteration:   100, Loss: 3.591
# Epoch: 4, Iteration:   200, Loss: 3.574
# Epoch: 4, Iteration:   300, Loss: 3.540
# Accuracy of the neural network on CIFAR_100 is: 18.90 %
# Accuracy of the neural network on CIFAR_100 is: 20.28 %
# Epoch: 5, Iteration:     0, Loss: 3.314
# Epoch: 5, Iteration:   100, Loss: 3.374
# Epoch: 5, Iteration:   200, Loss: 3.359
# Epoch: 5, Iteration:   300, Loss: 3.348
# Accuracy of the neural network on CIFAR_100 is: 21.33 %
# Accuracy of the neural network on CIFAR_100 is: 23.38 %
# Epoch: 6, Iteration:     0, Loss: 3.124
# Epoch: 6, Iteration:   100, Loss: 3.175
# Epoch: 6, Iteration:   200, Loss: 3.161
# Epoch: 6, Iteration:   300, Loss: 3.148
# Accuracy of the neural network on CIFAR_100 is: 24.11 %
# Accuracy of the neural network on CIFAR_100 is: 26.33 %
# Epoch: 7, Iteration:     0, Loss: 3.122
# Epoch: 7, Iteration:   100, Loss: 2.999
# Epoch: 7, Iteration:   200, Loss: 2.989
# Epoch: 7, Iteration:   300, Loss: 2.978
# Accuracy of the neural network on CIFAR_100 is: 26.09 %
# Accuracy of the neural network on CIFAR_100 is: 29.39 %
# Epoch: 8, Iteration:     0, Loss: 3.082
# Epoch: 8, Iteration:   100, Loss: 2.904
# Epoch: 8, Iteration:   200, Loss: 2.871
# Epoch: 8, Iteration:   300, Loss: 2.856
# Accuracy of the neural network on CIFAR_100 is: 31.02 %
# Accuracy of the neural network on CIFAR_100 is: 33.17 %
# Epoch: 9, Iteration:     0, Loss: 3.135
# Epoch: 9, Iteration:   100, Loss: 2.739
# Epoch: 9, Iteration:   200, Loss: 2.736
# Epoch: 9, Iteration:   300, Loss: 2.717
# Accuracy of the neural network on CIFAR_100 is: 33.49 %
# Accuracy of the neural network on CIFAR_100 is: 34.75 %
# Epoch: 10, Iteration:     0, Loss: 2.708
# Epoch: 10, Iteration:   100, Loss: 2.613
# Epoch: 10, Iteration:   200, Loss: 2.612
# Epoch: 10, Iteration:   300, Loss: 2.614
# Accuracy of the neural network on CIFAR_100 is: 33.99 %
# Accuracy of the neural network on CIFAR_100 is: 35.04 %
# Epoch: 11, Iteration:     0, Loss: 2.716
# Epoch: 11, Iteration:   100, Loss: 2.498
# Epoch: 11, Iteration:   200, Loss: 2.501
# Epoch: 11, Iteration:   300, Loss: 2.487
# Accuracy of the neural network on CIFAR_100 is: 38.99 %
# Accuracy of the neural network on CIFAR_100 is: 39.37 %
# Epoch: 12, Iteration:     0, Loss: 2.466
# Epoch: 12, Iteration:   100, Loss: 2.409
# Epoch: 12, Iteration:   200, Loss: 2.392
# Epoch: 12, Iteration:   300, Loss: 2.390
# Accuracy of the neural network on CIFAR_100 is: 40.48 %
# Accuracy of the neural network on CIFAR_100 is: 41.06 %
# Epoch: 13, Iteration:     0, Loss: 2.246
# Epoch: 13, Iteration:   100, Loss: 2.284
# Epoch: 13, Iteration:   200, Loss: 2.278
# Epoch: 13, Iteration:   300, Loss: 2.277
# Accuracy of the neural network on CIFAR_100 is: 42.28 %
# Accuracy of the neural network on CIFAR_100 is: 42.36 %
# Epoch: 14, Iteration:     0, Loss: 1.849
# Epoch: 14, Iteration:   100, Loss: 2.206
# Epoch: 14, Iteration:   200, Loss: 2.209
# Epoch: 14, Iteration:   300, Loss: 2.212
# Accuracy of the neural network on CIFAR_100 is: 43.88 %
# Accuracy of the neural network on CIFAR_100 is: 43.60 %
# Epoch: 15, Iteration:     0, Loss: 2.032
# Epoch: 15, Iteration:   100, Loss: 2.124
# Epoch: 15, Iteration:   200, Loss: 2.141
# Epoch: 15, Iteration:   300, Loss: 2.138
# Accuracy of the neural network on CIFAR_100 is: 43.86 %
# Accuracy of the neural network on CIFAR_100 is: 42.94 %
# Epoch: 16, Iteration:     0, Loss: 2.182
# Epoch: 16, Iteration:   100, Loss: 2.069
# Epoch: 16, Iteration:   200, Loss: 2.073
# Epoch: 16, Iteration:   300, Loss: 2.066
# Accuracy of the neural network on CIFAR_100 is: 46.05 %
# Accuracy of the neural network on CIFAR_100 is: 45.17 %
# Epoch: 17, Iteration:     0, Loss: 1.788
# Epoch: 17, Iteration:   100, Loss: 1.977
# Epoch: 17, Iteration:   200, Loss: 1.990
# Epoch: 17, Iteration:   300, Loss: 1.999
# Accuracy of the neural network on CIFAR_100 is: 47.16 %
# Accuracy of the neural network on CIFAR_100 is: 45.92 %
# Epoch: 18, Iteration:     0, Loss: 2.074
# Epoch: 18, Iteration:   100, Loss: 1.921
# Epoch: 18, Iteration:   200, Loss: 1.933
# Epoch: 18, Iteration:   300, Loss: 1.932
# Accuracy of the neural network on CIFAR_100 is: 49.29 %
# Accuracy of the neural network on CIFAR_100 is: 47.37 %
# Epoch: 19, Iteration:     0, Loss: 1.799
# Epoch: 19, Iteration:   100, Loss: 1.872
# Epoch: 19, Iteration:   200, Loss: 1.875
# Epoch: 19, Iteration:   300, Loss: 1.873
# Accuracy of the neural network on CIFAR_100 is: 50.04 %
# Accuracy of the neural network on CIFAR_100 is: 49.08 %
# Epoch: 20, Iteration:     0, Loss: 1.577
# Epoch: 20, Iteration:   100, Loss: 1.811
# Epoch: 20, Iteration:   200, Loss: 1.825
# Epoch: 20, Iteration:   300, Loss: 1.828
# Accuracy of the neural network on CIFAR_100 is: 51.80 %
# Accuracy of the neural network on CIFAR_100 is: 49.86 %
# Epoch: 21, Iteration:     0, Loss: 1.465
# Epoch: 21, Iteration:   100, Loss: 1.757
# Epoch: 21, Iteration:   200, Loss: 1.773
# Epoch: 21, Iteration:   300, Loss: 1.790
# Accuracy of the neural network on CIFAR_100 is: 51.68 %
# Accuracy of the neural network on CIFAR_100 is: 49.63 %
# Epoch: 22, Iteration:     0, Loss: 1.797
# Epoch: 22, Iteration:   100, Loss: 1.739
# Epoch: 22, Iteration:   200, Loss: 1.746
# Epoch: 22, Iteration:   300, Loss: 1.753
# Accuracy of the neural network on CIFAR_100 is: 52.44 %
# Accuracy of the neural network on CIFAR_100 is: 49.25 %
# Epoch: 23, Iteration:     0, Loss: 1.695
# Epoch: 23, Iteration:   100, Loss: 1.677
# Epoch: 23, Iteration:   200, Loss: 1.710
# Epoch: 23, Iteration:   300, Loss: 1.712
# Accuracy of the neural network on CIFAR_100 is: 53.12 %
# Accuracy of the neural network on CIFAR_100 is: 50.44 %
# Epoch: 24, Iteration:     0, Loss: 1.793
# Epoch: 24, Iteration:   100, Loss: 1.625
# Epoch: 24, Iteration:   200, Loss: 1.643
# Epoch: 24, Iteration:   300, Loss: 1.651
# Accuracy of the neural network on CIFAR_100 is: 54.71 %
# Accuracy of the neural network on CIFAR_100 is: 52.94 %
# Epoch: 25, Iteration:     0, Loss: 1.744
# Epoch: 25, Iteration:   100, Loss: 1.606
# Epoch: 25, Iteration:   200, Loss: 1.616
# Epoch: 25, Iteration:   300, Loss: 1.621
# Accuracy of the neural network on CIFAR_100 is: 55.01 %
# Accuracy of the neural network on CIFAR_100 is: 51.72 %
# Epoch: 26, Iteration:     0, Loss: 2.013
# Epoch: 26, Iteration:   100, Loss: 1.573
# Epoch: 26, Iteration:   200, Loss: 1.583
# Epoch: 26, Iteration:   300, Loss: 1.599
# Accuracy of the neural network on CIFAR_100 is: 56.90 %
# Accuracy of the neural network on CIFAR_100 is: 53.29 %
# Epoch: 27, Iteration:     0, Loss: 1.664
# Epoch: 27, Iteration:   100, Loss: 1.520
# Epoch: 27, Iteration:   200, Loss: 1.542
# Epoch: 27, Iteration:   300, Loss: 1.556
# Accuracy of the neural network on CIFAR_100 is: 57.67 %
# Accuracy of the neural network on CIFAR_100 is: 54.63 %
# Epoch: 28, Iteration:     0, Loss: 1.671
# Epoch: 28, Iteration:   100, Loss: 1.524
# Epoch: 28, Iteration:   200, Loss: 1.532
# Epoch: 28, Iteration:   300, Loss: 1.534
# Accuracy of the neural network on CIFAR_100 is: 58.31 %
# Accuracy of the neural network on CIFAR_100 is: 54.62 %
# Epoch: 29, Iteration:     0, Loss: 1.409
# Epoch: 29, Iteration:   100, Loss: 1.504
# Epoch: 29, Iteration:   200, Loss: 1.504
# Epoch: 29, Iteration:   300, Loss: 1.497
# Accuracy of the neural network on CIFAR_100 is: 60.04 %
# Accuracy of the neural network on CIFAR_100 is: 55.91 %
# Epoch: 30, Iteration:     0, Loss: 1.358
# Epoch: 30, Iteration:   100, Loss: 1.439
# Epoch: 30, Iteration:   200, Loss: 1.452
# Epoch: 30, Iteration:   300, Loss: 1.459
# Accuracy of the neural network on CIFAR_100 is: 58.61 %
# Accuracy of the neural network on CIFAR_100 is: 53.44 %
# Epoch: 31, Iteration:     0, Loss: 1.626
# Epoch: 31, Iteration:   100, Loss: 1.436
# Epoch: 31, Iteration:   200, Loss: 1.431
# Epoch: 31, Iteration:   300, Loss: 1.440
# Accuracy of the neural network on CIFAR_100 is: 60.27 %
# Accuracy of the neural network on CIFAR_100 is: 56.15 %
# Epoch: 32, Iteration:     0, Loss: 1.403
# Epoch: 32, Iteration:   100, Loss: 1.382
# Epoch: 32, Iteration:   200, Loss: 1.395
# Epoch: 32, Iteration:   300, Loss: 1.407
# Accuracy of the neural network on CIFAR_100 is: 60.94 %
# Accuracy of the neural network on CIFAR_100 is: 55.76 %
# Epoch: 33, Iteration:     0, Loss: 1.314
# Epoch: 33, Iteration:   100, Loss: 1.384
# Epoch: 33, Iteration:   200, Loss: 1.389
# Epoch: 33, Iteration:   300, Loss: 1.388
# Accuracy of the neural network on CIFAR_100 is: 61.41 %
# Accuracy of the neural network on CIFAR_100 is: 56.74 %
# Epoch: 34, Iteration:     0, Loss: 1.445
# Epoch: 34, Iteration:   100, Loss: 1.358
# Epoch: 34, Iteration:   200, Loss: 1.351
# Epoch: 34, Iteration:   300, Loss: 1.356
# Accuracy of the neural network on CIFAR_100 is: 62.11 %
# Accuracy of the neural network on CIFAR_100 is: 56.37 %
# Epoch: 35, Iteration:     0, Loss: 1.306
# Epoch: 35, Iteration:   100, Loss: 1.330
# Epoch: 35, Iteration:   200, Loss: 1.331
# Epoch: 35, Iteration:   300, Loss: 1.344
# Accuracy of the neural network on CIFAR_100 is: 63.10 %
# Accuracy of the neural network on CIFAR_100 is: 55.96 %
# Epoch: 36, Iteration:     0, Loss: 1.254
# Epoch: 36, Iteration:   100, Loss: 1.300
# Epoch: 36, Iteration:   200, Loss: 1.307
# Epoch: 36, Iteration:   300, Loss: 1.311
# Accuracy of the neural network on CIFAR_100 is: 63.40 %
# Accuracy of the neural network on CIFAR_100 is: 56.61 %
# Epoch: 37, Iteration:     0, Loss: 1.148
# Epoch: 37, Iteration:   100, Loss: 1.272
# Epoch: 37, Iteration:   200, Loss: 1.280
# Epoch: 37, Iteration:   300, Loss: 1.289
# Accuracy of the neural network on CIFAR_100 is: 62.41 %
# Accuracy of the neural network on CIFAR_100 is: 55.00 %
# Epoch: 38, Iteration:     0, Loss: 1.523
# Epoch: 38, Iteration:   100, Loss: 1.281
# Epoch: 38, Iteration:   200, Loss: 1.274
# Epoch: 38, Iteration:   300, Loss: 1.275
# Accuracy of the neural network on CIFAR_100 is: 64.83 %
# Accuracy of the neural network on CIFAR_100 is: 57.77 %
# Epoch: 39, Iteration:     0, Loss: 1.529
# Epoch: 39, Iteration:   100, Loss: 1.233
# Epoch: 39, Iteration:   200, Loss: 1.243
# Epoch: 39, Iteration:   300, Loss: 1.255
# Accuracy of the neural network on CIFAR_100 is: 65.20 %
# Accuracy of the neural network on CIFAR_100 is: 57.73 %
# Epoch: 40, Iteration:     0, Loss: 1.423
# Epoch: 40, Iteration:   100, Loss: 1.208
# Epoch: 40, Iteration:   200, Loss: 1.217
# Epoch: 40, Iteration:   300, Loss: 1.225
# Accuracy of the neural network on CIFAR_100 is: 65.77 %
# Accuracy of the neural network on CIFAR_100 is: 57.40 %
# Epoch: 41, Iteration:     0, Loss: 1.101
# Epoch: 41, Iteration:   100, Loss: 1.227
# Epoch: 41, Iteration:   200, Loss: 1.217
# Epoch: 41, Iteration:   300, Loss: 1.224
# Accuracy of the neural network on CIFAR_100 is: 65.70 %
# Accuracy of the neural network on CIFAR_100 is: 57.35 %
# Epoch: 42, Iteration:     0, Loss: 1.240
# Epoch: 42, Iteration:   100, Loss: 1.202
# Epoch: 42, Iteration:   200, Loss: 1.196
# Epoch: 42, Iteration:   300, Loss: 1.205
# Accuracy of the neural network on CIFAR_100 is: 66.60 %
# Accuracy of the neural network on CIFAR_100 is: 58.17 %
# Epoch: 43, Iteration:     0, Loss: 1.333
# Epoch: 43, Iteration:   100, Loss: 1.211
# Epoch: 43, Iteration:   200, Loss: 1.192
# Epoch: 43, Iteration:   300, Loss: 1.190
# Accuracy of the neural network on CIFAR_100 is: 65.58 %
# Accuracy of the neural network on CIFAR_100 is: 57.67 %
# Epoch: 44, Iteration:     0, Loss: 0.857
# Epoch: 44, Iteration:   100, Loss: 1.128
# Epoch: 44, Iteration:   200, Loss: 1.146
# Epoch: 44, Iteration:   300, Loss: 1.154
# Accuracy of the neural network on CIFAR_100 is: 67.38 %
# Accuracy of the neural network on CIFAR_100 is: 58.49 %
# Epoch: 45, Iteration:     0, Loss: 1.038
# Epoch: 45, Iteration:   100, Loss: 1.143
# Epoch: 45, Iteration:   200, Loss: 1.140
# Epoch: 45, Iteration:   300, Loss: 1.146
# Accuracy of the neural network on CIFAR_100 is: 67.43 %
# Accuracy of the neural network on CIFAR_100 is: 58.08 %
# Epoch: 46, Iteration:     0, Loss: 1.156
# Epoch: 46, Iteration:   100, Loss: 1.108
# Epoch: 46, Iteration:   200, Loss: 1.104
# Epoch: 46, Iteration:   300, Loss: 1.125
# Accuracy of the neural network on CIFAR_100 is: 66.53 %
# Accuracy of the neural network on CIFAR_100 is: 58.03 %
# Epoch: 47, Iteration:     0, Loss: 1.316
# Epoch: 47, Iteration:   100, Loss: 1.101
# Epoch: 47, Iteration:   200, Loss: 1.119
# Epoch: 47, Iteration:   300, Loss: 1.121
# Accuracy of the neural network on CIFAR_100 is: 68.12 %
# Accuracy of the neural network on CIFAR_100 is: 58.40 %
# Epoch: 48, Iteration:     0, Loss: 1.089
# Epoch: 48, Iteration:   100, Loss: 1.083
# Epoch: 48, Iteration:   200, Loss: 1.096
# Epoch: 48, Iteration:   300, Loss: 1.103
# Accuracy of the neural network on CIFAR_100 is: 69.08 %
# Accuracy of the neural network on CIFAR_100 is: 59.35 %
# Epoch: 49, Iteration:     0, Loss: 1.231
# Epoch: 49, Iteration:   100, Loss: 1.062
# Epoch: 49, Iteration:   200, Loss: 1.080
# Epoch: 49, Iteration:   300, Loss: 1.080
# Accuracy of the neural network on CIFAR_100 is: 69.45 %
# Accuracy of the neural network on CIFAR_100 is: 59.69 %
# Epoch: 50, Iteration:     0, Loss: 0.981
# Epoch: 50, Iteration:   100, Loss: 1.050
# Epoch: 50, Iteration:   200, Loss: 1.064
# Epoch: 50, Iteration:   300, Loss: 1.070
# Accuracy of the neural network on CIFAR_100 is: 69.79 %
# Accuracy of the neural network on CIFAR_100 is: 59.12 %
# Epoch: 51, Iteration:     0, Loss: 0.886
# Epoch: 51, Iteration:   100, Loss: 1.037
# Epoch: 51, Iteration:   200, Loss: 1.054
# Epoch: 51, Iteration:   300, Loss: 1.055
# Accuracy of the neural network on CIFAR_100 is: 69.59 %
# Accuracy of the neural network on CIFAR_100 is: 59.43 %
# Epoch: 52, Iteration:     0, Loss: 1.193
# Epoch: 52, Iteration:   100, Loss: 1.005
# Epoch: 52, Iteration:   200, Loss: 1.037
# Epoch: 52, Iteration:   300, Loss: 1.044
# Accuracy of the neural network on CIFAR_100 is: 69.10 %
# Accuracy of the neural network on CIFAR_100 is: 58.47 %
# Epoch: 53, Iteration:     0, Loss: 0.883
# Epoch: 53, Iteration:   100, Loss: 1.007
# Epoch: 53, Iteration:   200, Loss: 1.023
# Epoch: 53, Iteration:   300, Loss: 1.032
# Accuracy of the neural network on CIFAR_100 is: 70.02 %
# Accuracy of the neural network on CIFAR_100 is: 59.30 %
# Epoch: 54, Iteration:     0, Loss: 0.921
# Epoch: 54, Iteration:   100, Loss: 1.001
# Epoch: 54, Iteration:   200, Loss: 1.014
# Epoch: 54, Iteration:   300, Loss: 1.009
# Accuracy of the neural network on CIFAR_100 is: 70.87 %
# Accuracy of the neural network on CIFAR_100 is: 59.71 %
# Epoch: 55, Iteration:     0, Loss: 0.997
# Epoch: 55, Iteration:   100, Loss: 0.999
# Epoch: 55, Iteration:   200, Loss: 1.006
# Epoch: 55, Iteration:   300, Loss: 1.013
# Accuracy of the neural network on CIFAR_100 is: 71.23 %
# Accuracy of the neural network on CIFAR_100 is: 60.04 %
# Epoch: 56, Iteration:     0, Loss: 1.225
# Epoch: 56, Iteration:   100, Loss: 0.974
# Epoch: 56, Iteration:   200, Loss: 0.990
# Epoch: 56, Iteration:   300, Loss: 0.992
# Accuracy of the neural network on CIFAR_100 is: 71.56 %
# Accuracy of the neural network on CIFAR_100 is: 59.97 %
# Epoch: 57, Iteration:     0, Loss: 1.058
# Epoch: 57, Iteration:   100, Loss: 0.981
# Epoch: 57, Iteration:   200, Loss: 0.984
# Epoch: 57, Iteration:   300, Loss: 0.980
# Accuracy of the neural network on CIFAR_100 is: 71.73 %
# Accuracy of the neural network on CIFAR_100 is: 59.89 %
# Epoch: 58, Iteration:     0, Loss: 1.200
# Epoch: 58, Iteration:   100, Loss: 0.970
# Epoch: 58, Iteration:   200, Loss: 0.973
# Epoch: 58, Iteration:   300, Loss: 0.971
# Accuracy of the neural network on CIFAR_100 is: 71.23 %
# Accuracy of the neural network on CIFAR_100 is: 59.62 %
# Epoch: 59, Iteration:     0, Loss: 0.983
# Epoch: 59, Iteration:   100, Loss: 0.961
# Epoch: 59, Iteration:   200, Loss: 0.953
# Epoch: 59, Iteration:   300, Loss: 0.956
# Accuracy of the neural network on CIFAR_100 is: 72.27 %
# Accuracy of the neural network on CIFAR_100 is: 59.99 %
# Epoch: 60, Iteration:     0, Loss: 0.984
# Epoch: 60, Iteration:   100, Loss: 0.907
# Epoch: 60, Iteration:   200, Loss: 0.936
# Epoch: 60, Iteration:   300, Loss: 0.944
# Accuracy of the neural network on CIFAR_100 is: 72.73 %
# Accuracy of the neural network on CIFAR_100 is: 59.85 %
# Epoch: 61, Iteration:     0, Loss: 0.745
# Epoch: 61, Iteration:   100, Loss: 0.917
# Epoch: 61, Iteration:   200, Loss: 0.931
# Epoch: 61, Iteration:   300, Loss: 0.946
# Accuracy of the neural network on CIFAR_100 is: 72.37 %
# Accuracy of the neural network on CIFAR_100 is: 59.77 %
# Epoch: 62, Iteration:     0, Loss: 0.952
# Epoch: 62, Iteration:   100, Loss: 0.894
# Epoch: 62, Iteration:   200, Loss: 0.916
# Epoch: 62, Iteration:   300, Loss: 0.927
# Accuracy of the neural network on CIFAR_100 is: 72.85 %
# Accuracy of the neural network on CIFAR_100 is: 60.10 %
# Epoch: 63, Iteration:     0, Loss: 0.846
# Epoch: 63, Iteration:   100, Loss: 0.906
# Epoch: 63, Iteration:   200, Loss: 0.914
# Epoch: 63, Iteration:   300, Loss: 0.916
# Accuracy of the neural network on CIFAR_100 is: 73.25 %
# Accuracy of the neural network on CIFAR_100 is: 60.22 %
# Epoch: 64, Iteration:     0, Loss: 1.158
# Epoch: 64, Iteration:   100, Loss: 0.912
# Epoch: 64, Iteration:   200, Loss: 0.913
# Epoch: 64, Iteration:   300, Loss: 0.915
# Accuracy of the neural network on CIFAR_100 is: 73.16 %
# Accuracy of the neural network on CIFAR_100 is: 60.05 %
# Epoch: 65, Iteration:     0, Loss: 1.224
# Epoch: 65, Iteration:   100, Loss: 0.902
# Epoch: 65, Iteration:   200, Loss: 0.910
# Epoch: 65, Iteration:   300, Loss: 0.910
# Accuracy of the neural network on CIFAR_100 is: 73.62 %
# Accuracy of the neural network on CIFAR_100 is: 60.28 %
# Epoch: 66, Iteration:     0, Loss: 0.898
# Epoch: 66, Iteration:   100, Loss: 0.872
# Epoch: 66, Iteration:   200, Loss: 0.884
# Epoch: 66, Iteration:   300, Loss: 0.890
# Accuracy of the neural network on CIFAR_100 is: 74.21 %
# Accuracy of the neural network on CIFAR_100 is: 60.26 %
# Epoch: 67, Iteration:     0, Loss: 0.969
# Epoch: 67, Iteration:   100, Loss: 0.892
# Epoch: 67, Iteration:   200, Loss: 0.885
# Epoch: 67, Iteration:   300, Loss: 0.887
# Accuracy of the neural network on CIFAR_100 is: 74.11 %
# Accuracy of the neural network on CIFAR_100 is: 60.79 %
# Epoch: 68, Iteration:     0, Loss: 0.820
# Epoch: 68, Iteration:   100, Loss: 0.876
# Epoch: 68, Iteration:   200, Loss: 0.879
# Epoch: 68, Iteration:   300, Loss: 0.876
# Accuracy of the neural network on CIFAR_100 is: 74.31 %
# Accuracy of the neural network on CIFAR_100 is: 60.75 %
# Epoch: 69, Iteration:     0, Loss: 0.703
# Epoch: 69, Iteration:   100, Loss: 0.846
# Epoch: 69, Iteration:   200, Loss: 0.857
# Epoch: 69, Iteration:   300, Loss: 0.866
# Accuracy of the neural network on CIFAR_100 is: 74.61 %
# Accuracy of the neural network on CIFAR_100 is: 60.89 %
# Epoch: 70, Iteration:     0, Loss: 0.865
# Epoch: 70, Iteration:   100, Loss: 0.843
# Epoch: 70, Iteration:   200, Loss: 0.859
# Epoch: 70, Iteration:   300, Loss: 0.867
# Accuracy of the neural network on CIFAR_100 is: 74.56 %
# Accuracy of the neural network on CIFAR_100 is: 60.81 %
# Epoch: 71, Iteration:     0, Loss: 0.866
# Epoch: 71, Iteration:   100, Loss: 0.841
# Epoch: 71, Iteration:   200, Loss: 0.855
# Epoch: 71, Iteration:   300, Loss: 0.859
# Accuracy of the neural network on CIFAR_100 is: 74.90 %
# Accuracy of the neural network on CIFAR_100 is: 60.95 %
# Epoch: 72, Iteration:     0, Loss: 0.884
# Epoch: 72, Iteration:   100, Loss: 0.827
# Epoch: 72, Iteration:   200, Loss: 0.841
# Epoch: 72, Iteration:   300, Loss: 0.846
# Accuracy of the neural network on CIFAR_100 is: 74.44 %
# Accuracy of the neural network on CIFAR_100 is: 60.38 %
# Epoch: 73, Iteration:     0, Loss: 0.831
# Epoch: 73, Iteration:   100, Loss: 0.837
# Epoch: 73, Iteration:   200, Loss: 0.839
# Epoch: 73, Iteration:   300, Loss: 0.841
# Accuracy of the neural network on CIFAR_100 is: 74.83 %
# Accuracy of the neural network on CIFAR_100 is: 60.63 %
# Epoch: 74, Iteration:     0, Loss: 0.785
# Epoch: 74, Iteration:   100, Loss: 0.815
# Epoch: 74, Iteration:   200, Loss: 0.823
# Epoch: 74, Iteration:   300, Loss: 0.835
# Accuracy of the neural network on CIFAR_100 is: 75.77 %
# Accuracy of the neural network on CIFAR_100 is: 61.02 %
# Epoch: 75, Iteration:     0, Loss: 0.769
# Epoch: 75, Iteration:   100, Loss: 0.810
# Epoch: 75, Iteration:   200, Loss: 0.816
# Epoch: 75, Iteration:   300, Loss: 0.831
# Accuracy of the neural network on CIFAR_100 is: 75.48 %
# Accuracy of the neural network on CIFAR_100 is: 60.79 %
# Epoch: 76, Iteration:     0, Loss: 0.783
# Epoch: 76, Iteration:   100, Loss: 0.831
# Epoch: 76, Iteration:   200, Loss: 0.833
# Epoch: 76, Iteration:   300, Loss: 0.829
# Accuracy of the neural network on CIFAR_100 is: 75.51 %
# Accuracy of the neural network on CIFAR_100 is: 60.47 %
# Epoch: 77, Iteration:     0, Loss: 0.958
# Epoch: 77, Iteration:   100, Loss: 0.807
# Epoch: 77, Iteration:   200, Loss: 0.814
# Epoch: 77, Iteration:   300, Loss: 0.814
# Accuracy of the neural network on CIFAR_100 is: 75.77 %
# Accuracy of the neural network on CIFAR_100 is: 60.96 %
# Epoch: 78, Iteration:     0, Loss: 0.732
# Epoch: 78, Iteration:   100, Loss: 0.815
# Epoch: 78, Iteration:   200, Loss: 0.809
# Epoch: 78, Iteration:   300, Loss: 0.809
# Accuracy of the neural network on CIFAR_100 is: 76.05 %
# Accuracy of the neural network on CIFAR_100 is: 61.08 %
# Epoch: 79, Iteration:     0, Loss: 0.682
# Epoch: 79, Iteration:   100, Loss: 0.805
# Epoch: 79, Iteration:   200, Loss: 0.806
# Epoch: 79, Iteration:   300, Loss: 0.809
# Accuracy of the neural network on CIFAR_100 is: 76.10 %
# Accuracy of the neural network on CIFAR_100 is: 60.95 %
# Epoch: 80, Iteration:     0, Loss: 0.667
# Epoch: 80, Iteration:   100, Loss: 0.802
# Epoch: 80, Iteration:   200, Loss: 0.796
# Epoch: 80, Iteration:   300, Loss: 0.799
# Accuracy of the neural network on CIFAR_100 is: 75.91 %
# Accuracy of the neural network on CIFAR_100 is: 60.66 %
# Epoch: 81, Iteration:     0, Loss: 0.555
# Epoch: 81, Iteration:   100, Loss: 0.788
# Epoch: 81, Iteration:   200, Loss: 0.796
# Epoch: 81, Iteration:   300, Loss: 0.794
# Accuracy of the neural network on CIFAR_100 is: 76.20 %
# Accuracy of the neural network on CIFAR_100 is: 61.26 %
# Epoch: 82, Iteration:     0, Loss: 0.720
# Epoch: 82, Iteration:   100, Loss: 0.802
# Epoch: 82, Iteration:   200, Loss: 0.794
# Epoch: 82, Iteration:   300, Loss: 0.790
# Accuracy of the neural network on CIFAR_100 is: 76.42 %
# Accuracy of the neural network on CIFAR_100 is: 61.07 %
# Epoch: 83, Iteration:     0, Loss: 1.011
# Epoch: 83, Iteration:   100, Loss: 0.775
# Epoch: 83, Iteration:   200, Loss: 0.787
# Epoch: 83, Iteration:   300, Loss: 0.787
# Accuracy of the neural network on CIFAR_100 is: 76.47 %
# Accuracy of the neural network on CIFAR_100 is: 60.70 %
# Epoch: 84, Iteration:     0, Loss: 0.796
# Epoch: 84, Iteration:   100, Loss: 0.789
# Epoch: 84, Iteration:   200, Loss: 0.782
# Epoch: 84, Iteration:   300, Loss: 0.783
# Accuracy of the neural network on CIFAR_100 is: 76.47 %
# Accuracy of the neural network on CIFAR_100 is: 61.22 %
# Epoch: 85, Iteration:     0, Loss: 0.800
# Epoch: 85, Iteration:   100, Loss: 0.776
# Epoch: 85, Iteration:   200, Loss: 0.773
# Epoch: 85, Iteration:   300, Loss: 0.778
# Accuracy of the neural network on CIFAR_100 is: 77.12 %
# Accuracy of the neural network on CIFAR_100 is: 61.15 %
# Epoch: 86, Iteration:     0, Loss: 0.766
# Epoch: 86, Iteration:   100, Loss: 0.763
# Epoch: 86, Iteration:   200, Loss: 0.765
# Epoch: 86, Iteration:   300, Loss: 0.772
# Accuracy of the neural network on CIFAR_100 is: 76.84 %
# Accuracy of the neural network on CIFAR_100 is: 61.55 %
# Epoch: 87, Iteration:     0, Loss: 0.647
# Epoch: 87, Iteration:   100, Loss: 0.761
# Epoch: 87, Iteration:   200, Loss: 0.777
# Epoch: 87, Iteration:   300, Loss: 0.778
# Accuracy of the neural network on CIFAR_100 is: 76.88 %
# Accuracy of the neural network on CIFAR_100 is: 61.31 %
# Epoch: 88, Iteration:     0, Loss: 0.732
# Epoch: 88, Iteration:   100, Loss: 0.764
# Epoch: 88, Iteration:   200, Loss: 0.758
# Epoch: 88, Iteration:   300, Loss: 0.767
# Accuracy of the neural network on CIFAR_100 is: 76.97 %
# Accuracy of the neural network on CIFAR_100 is: 60.84 %
# Epoch: 89, Iteration:     0, Loss: 0.732
# Epoch: 89, Iteration:   100, Loss: 0.760
# Epoch: 89, Iteration:   200, Loss: 0.760
# Epoch: 89, Iteration:   300, Loss: 0.768
# Accuracy of the neural network on CIFAR_100 is: 76.86 %
# Accuracy of the neural network on CIFAR_100 is: 61.28 %
# Epoch: 90, Iteration:     0, Loss: 0.825
# Epoch: 90, Iteration:   100, Loss: 0.756
# Epoch: 90, Iteration:   200, Loss: 0.755
# Epoch: 90, Iteration:   300, Loss: 0.760
# Accuracy of the neural network on CIFAR_100 is: 77.04 %
# Accuracy of the neural network on CIFAR_100 is: 61.20 %
# Epoch: 91, Iteration:     0, Loss: 0.862
# Epoch: 91, Iteration:   100, Loss: 0.753
# Epoch: 91, Iteration:   200, Loss: 0.754
# Epoch: 91, Iteration:   300, Loss: 0.754
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-50ff0db577a1> in <module>()
#      65     torch.save(net.state_dict(), PATH)
#      66
# ---> 67 trainNetwork()
#
# <ipython-input-9-50ff0db577a1> in trainNetwork()
#      49                 print("Epoch: %d, Iteration: %5d, Loss: %.3f" % ((e + 1), (i), (accLoss / (i + 1))))
#      50
# ---> 51         train_loss, train_acc = evaluate(net, False, os.path.join(SAVE_DIR, "eval/train_eval7"))
#      52         val_loss, val_acc = evaluate(net, True, os.path.join(SAVE_DIR, "eval/test_eval7"))
#      53
#
# <ipython-input-7-2739ed7448cb> in evaluate(net, type, save_path)
#      52                 _, predictions = torch.max(output.data, 1)
#      53                 total += labels.size(0)
# ---> 54                 accLoss += loss.item()
#      55                 correct += (predictions == labels).sum().item()
#      56                 for j in range(labels.size(0)):
#
# KeyboardInterrupt:
