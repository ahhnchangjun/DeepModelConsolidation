# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
SAVE_DIR = '/content/drive/MyDrive/Zavrsni'

# %%
conf_matrix = pd.read_csv(os.path.join(SAVE_DIR, 'final_eval_data/final_confusion_matrix.csv'))
conf_matrix = conf_matrix.iloc[:, 1:]
conf_matrix = conf_matrix.div(100)

# %%
plt.figure(figsize=(15,13))
plt.title('Confusion matrix')
sns.heatmap(conf_matrix, vmin=0.0, vmax=1.0)
